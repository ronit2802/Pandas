# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#Data Frame

df = pd.DataFrame([11,21,31],columns=['Col_Name'])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        21
# 2        31

# %%
data = {
    
    'Name' : ['Andrew','Steve','Zuck','Larry'],
    'Age' : [48,58,38,30],
    'Salary': [25000,36000,45000,55000]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Salary
# 0  Andrew   48   25000
# 1   Steve   58   36000
# 2    Zuck   38   45000
# 3   Larry   30   55000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head(2)
# Out:
#      Name  Age  Salary
# 0  Andrew   48   25000
# 1   Steve   58   36000

# %%
df.tail(2)
# Out:
#     Name  Age  Salary
# 2   Zuck   38   45000
# 3  Larry   30   55000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
#Remaining Columns
df.rename(columns={'Salary':'Monthly_Salary'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe() # Showing Statistical overview of the values
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   43.500000    40250.000000
# std    12.151817    12789.970029
# min    30.000000    25000.000000
# 25%    36.000000    33250.000000
# 50%    43.000000    40500.000000
# 75%    50.500000    47500.000000
# max    58.000000    55000.000000

# %%
#Save and Load the Data from csv

df.to_csv('Test_data.csv',index=False) #export Dataframe

# %%
load_dataframe = pd.read_csv('Test_data.csv') #Load DataFrame
load_dataframe
# Out:
#      Name  Age  Monthly_Salary
# 0  Andrew   48           25000
# 1   Steve   58           36000
# 2    Zuck   38           45000
# 3   Larry   30           55000

# %%
#Rows and ColumnsSelection

df[['Name','Monthly_Salary']] # Selecting Single Column in the DataFrame
# Out:
#      Name  Monthly_Salary
# 0  Andrew           25000
# 1   Steve           36000
# 2    Zuck           45000
# 3   Larry           55000

# %%
df.loc[(df.Name == 'Zuck') & (df.Age > 30)] # Row Selection on the bases of Name.
# Out:
#    Name  Age  Monthly_Salary
# 2  Zuck   38           45000

# %%
df.iloc[0]
# Out:
# Name              Andrew
# Age                   48
# Monthly_Salary     25000
# Name: 0, dtype: object

# %% [markdown]
# ### Filter the Data

# %%
df
# Out:
#      Name  Age  Monthly_Salary
# 0  Andrew   48           25000
# 1   Steve   58           36000
# 2    Zuck   38           45000
# 3   Larry   30           55000

# %%
df['Age'] >= 35
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# Name: Age, dtype: bool

# %%
df[df['Age'] >= 40 ]
# Out:
#      Name  Age  Monthly_Salary
# 0  Andrew   48           25000
# 1   Steve   58           36000

# %%
df[(df['Age'] >= 35) & (df['Monthly_Salary'] >= 24000)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Andrew   48           25000
# 1   Steve   58           36000
# 2    Zuck   38           45000

# %%
df.where(df['Age'] >= 40)
# Out:
#      Name   Age  Monthly_Salary
# 0  Andrew  48.0         25000.0
# 1   Steve  58.0         36000.0
# 2     NaN   NaN             NaN
# 3     NaN   NaN             NaN

# %% [markdown]
# ### Rows and Columns Operation (Update, Add, Delete)

# %%
df
# Out:
#      Name  Age  Monthly_Salary
# 0  Andrew   48           25000
# 1   Steve   58           36000
# 2    Zuck   38           45000
# 3   Larry   30           55000

# %%
# Add new column 
df['Team'] = ['CEO','HR','Sr Dev','Jr Dev']

# %%
df
# Out:
#      Name  Age  Monthly_Salary    Team
# 0  Andrew   48           25000     CEO
# 1   Steve   58           36000      HR
# 2    Zuck   38           45000  Sr Dev
# 3   Larry   30           55000  Jr Dev

# %%
df['Bonus'] = df['Monthly_Salary'] * 0.2 

df
# Out:
#      Name  Age  Monthly_Salary    Team    Bonus
# 0  Andrew   48           25000     CEO   5000.0
# 1   Steve   58           36000      HR   7200.0
# 2    Zuck   38           45000  Sr Dev   9000.0
# 3   Larry   30           55000  Jr Dev  11000.0

# %%
# Adding New Row 

df.loc[len(df)] = ['Junaid',48,25000,'Peon',400]

# %%
df
# Out:
#            Name  Age  Monthly_Salary    Team    Bonus
# 0        Andrew   48           25000     CEO   5000.0
# 1         Steve   58           36000      HR   7200.0
# 2          Zuck   38           45000  Sr Dev   9000.0
# 3         Larry   30           55000  Jr Dev  11000.0
# 4  Junai Ansari   48           25000    Peon    400.0
# 5        Junaid   48           25000    Peon    400.0

# %%
len(df)
# Out:
# 6

# %%
#update the Value
df.loc[5,'Name'] = 'Mathew'

# %%
df
# Out:
#      Name  Age  Monthly_Salary    Team    Bonus
# 0  Andrew   48           25000     CEO   5000.0
# 1   Steve   58           36000      HR   7200.0
# 2    Zuck   38           45000  Sr Dev   9000.0
# 3   Larry   30           55000  Jr Dev  11000.0
# 4  Junaid   48           25000    Peon    400.0
# 5  Mathew   48           25000    Peon    400.0

# %%
df.loc[4,'Name'] = 'Stefan'

# %%
df
# Out:
#      Name  Age  Monthly_Salary    Team    Bonus
# 0  Andrew   48           25000     CEO   5000.0
# 1   Steve   58           36000      HR   7200.0
# 2    Zuck   38           45000  Sr Dev   9000.0
# 3   Larry   30           55000  Jr Dev  11000.0
# 4  Stefan   48           25000    Peon    400.0
# 5  Mathew   48           25000    Peon    400.0

# %%
#Updating the value using column value 
df.loc[df.Name == 'Stefan', 'Team'] = 'WardBoy'

# %%
df
# Out:
#      Name  Age  Monthly_Salary     Team    Bonus
# 0  Andrew   48           25000      CEO   5000.0
# 1   Steve   58           36000       HR   7200.0
# 2    Zuck   38           45000   Sr Dev   9000.0
# 3   Larry   30           55000   Jr Dev  11000.0
# 4  Stefan   48           25000  WardBoy    400.0
# 5  Mathew   48           25000     Peon    400.0

# %%
#Dropping and Deleting 

df.drop(df[df.Name == 'Mathew'].index,inplace=True)

# %%
df
# Out:
#      Name  Age  Monthly_Salary     Team    Bonus
# 0  Andrew   48           25000      CEO   5000.0
# 1   Steve   58           36000       HR   7200.0
# 2    Zuck   38           45000   Sr Dev   9000.0
# 3   Larry   30           55000   Jr Dev  11000.0
# 4  Stefan   48           25000  WardBoy    400.0

# %%
# Sort Values
df.sort_values('Age',ascending=False)
# Out:
#      Name  Age  Monthly_Salary     Team    Bonus
# 1   Steve   58           36000       HR   7200.0
# 0  Andrew   48           25000      CEO   5000.0
# 4  Stefan   48           25000  WardBoy    400.0
# 2    Zuck   38           45000   Sr Dev   9000.0
# 3   Larry   30           55000   Jr Dev  11000.0

# %% [markdown]
# ### Working with Date Time Values

# %%
df['DOJ'] = ['2024-01-02','2024-02-01','2024-05-01','2024-10-01','2024-11-01','2024-12-01']
